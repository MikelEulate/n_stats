# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /home/mikel/.local/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
df = pd.read_csv('nba_final_v02.csv', index_col=0)

# %%
df.head()
# Out:
#    RLL_HOME_+/-  RLL_HOME_3P  RLL_HOME_3P%  RLL_HOME_3PA  RLL_HOME_3PAr  \
# 0           NaN     8.961052      0.469812     19.617369       0.257581
# 1           NaN     6.751715      0.393028     17.353576       0.197942
# 2           NaN     7.486581      0.378252     20.025380       0.234317
# 3           NaN     6.025633      0.331759     18.330054       0.233360
# 4           NaN     6.683740      0.343413     19.458822       0.230180
#
#    RLL_HOME_AST  RLL_HOME_AST%  RLL_HOME_BLK  RLL_HOME_BLK%  RLL_HOME_DRB  \
# 0     24.136962      63.995856      6.208568      10.053524     29.890207
# 1     24.795290      58.596547      6.382836       9.591609     33.158019
# 2     26.948306      65.177343      5.276481       7.932820     32.193527
# 3     21.751787      61.620177      4.778314       8.058415     31.846629
# 4     22.835760      57.677442      6.413042       9.873795     32.089887
#
#    ...         DATE   START               VISITOR    PTS  \
# ...

# %%
len(df)
# Out:
# 13002

# %%
df.columns
# Out:
# Index(['RLL_HOME_+/-', 'RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA',
#        'RLL_HOME_3PAr', 'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK',
#        'RLL_HOME_BLK%', 'RLL_HOME_DRB', 'RLL_HOME_DRB%', 'RLL_HOME_DRtg',
#        'RLL_HOME_FG', 'RLL_HOME_FG%', 'RLL_HOME_FGA', 'RLL_HOME_FT',
#        'RLL_HOME_FT%', 'RLL_HOME_FTA', 'RLL_HOME_FTr', 'RLL_HOME_MP',
#        'RLL_HOME_ORB', 'RLL_HOME_ORB%', 'RLL_HOME_ORtg', 'RLL_HOME_PF',
#        'RLL_HOME_PTS', 'RLL_HOME_STL', 'RLL_HOME_STL%', 'RLL_HOME_TOV',
#        'RLL_HOME_TOV%', 'RLL_HOME_TRB', 'RLL_HOME_TRB%', 'RLL_HOME_TS%',
#        'RLL_HOME_USG%', 'RLL_HOME_eFG%', 'RLL_VISITOR_+/-', 'RLL_VISITOR_3P',
#        'RLL_VISITOR_3P%', 'RLL_VISITOR_3PA', 'RLL_VISITOR_3PAr',
#        'RLL_VISITOR_AST', 'RLL_VISITOR_AST%', 'RLL_VISITOR_BLK',
#        'RLL_VISITOR_BLK%', 'RLL_VISITOR_DRB', 'RLL_VISITOR_DRB%',
#        'RLL_VISITOR_DRtg', 'RLL_VISITOR_FG', 'RLL_VISITOR_FG%',
# ...

# %%
df.describe()
# Out:
#        RLL_HOME_+/-   RLL_HOME_3P  RLL_HOME_3P%  RLL_HOME_3PA  RLL_HOME_3PAr  \
# count           0.0  12964.000000  12964.000000  12964.000000   12964.000000
# mean            NaN      8.318470      0.357604     23.105023       0.275350
# std             NaN      2.549087      0.046375      6.294044       0.068890
# min             NaN      1.934725      0.188775      7.110111       0.087458
# 25%             NaN      6.450855      0.328200     18.392919       0.225232
# 50%             NaN      8.126024      0.358324     22.501179       0.270632
# 75%             NaN     10.054052      0.387248     27.272826       0.323952
# max             NaN     18.401353      0.536412     48.095504       0.538651
#
#        RLL_HOME_AST  RLL_HOME_AST%  RLL_HOME_BLK  RLL_HOME_BLK%  RLL_HOME_DRB  \
# count  12964.000000   12964.000000  12964.000000   12964.000000  12964.000000
# mean      22.796757      59.030333      5.141978       8.489510     32.746489
# ...

# %%
df.loc[1229]
# Out:
# RLL_HOME_+/-                       NaN
# RLL_HOME_3P                    5.89134
# RLL_HOME_3P%                  0.429474
# RLL_HOME_3PA                    14.688
# RLL_HOME_3PAr                 0.177038
# RLL_HOME_AST                   21.5717
# RLL_HOME_AST%                  60.3874
# RLL_HOME_BLK                   4.35686
# RLL_HOME_BLK%                  6.62289
# RLL_HOME_DRB                   29.2301
# RLL_HOME_DRB%                  72.9896
# RLL_HOME_DRtg                  107.353
# RLL_HOME_FG                    35.7818
# RLL_HOME_FG%                  0.435832
# RLL_HOME_FGA                   82.5227
# RLL_HOME_FT                     16.836
# RLL_HOME_FT%                  0.780511
# RLL_HOME_FTA                   21.4007
# RLL_HOME_FTr                  0.261738
# RLL_HOME_MP                    245.574
# RLL_HOME_ORB                   12.7619
# RLL_HOME_ORB%                  28.9068
# RLL_HOME_ORtg                  103.222
# RLL_HOME_PF                    23.0081
# ...

# %%
#df = df[:1229]

# %%
df.columns
# Out:
# Index(['RLL_HOME_+/-', 'RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA',
#        'RLL_HOME_3PAr', 'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK',
#        'RLL_HOME_BLK%', 'RLL_HOME_DRB', 'RLL_HOME_DRB%', 'RLL_HOME_DRtg',
#        'RLL_HOME_FG', 'RLL_HOME_FG%', 'RLL_HOME_FGA', 'RLL_HOME_FT',
#        'RLL_HOME_FT%', 'RLL_HOME_FTA', 'RLL_HOME_FTr', 'RLL_HOME_MP',
#        'RLL_HOME_ORB', 'RLL_HOME_ORB%', 'RLL_HOME_ORtg', 'RLL_HOME_PF',
#        'RLL_HOME_PTS', 'RLL_HOME_STL', 'RLL_HOME_STL%', 'RLL_HOME_TOV',
#        'RLL_HOME_TOV%', 'RLL_HOME_TRB', 'RLL_HOME_TRB%', 'RLL_HOME_TS%',
#        'RLL_HOME_USG%', 'RLL_HOME_eFG%', 'RLL_VISITOR_+/-', 'RLL_VISITOR_3P',
#        'RLL_VISITOR_3P%', 'RLL_VISITOR_3PA', 'RLL_VISITOR_3PAr',
#        'RLL_VISITOR_AST', 'RLL_VISITOR_AST%', 'RLL_VISITOR_BLK',
#        'RLL_VISITOR_BLK%', 'RLL_VISITOR_DRB', 'RLL_VISITOR_DRB%',
#        'RLL_VISITOR_DRtg', 'RLL_VISITOR_FG', 'RLL_VISITOR_FG%',
# ...

# %%
cols_to_shift = ['RLL_HOME_+/-', 'RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA',
       'RLL_HOME_3PAr', 'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK',
       'RLL_HOME_BLK%', 'RLL_HOME_DRB', 'RLL_HOME_DRB%', 'RLL_HOME_DRtg',
       'RLL_HOME_FG', 'RLL_HOME_FG%', 'RLL_HOME_FGA', 'RLL_HOME_FT',
       'RLL_HOME_FT%', 'RLL_HOME_FTA', 'RLL_HOME_FTr', 'RLL_HOME_MP',
       'RLL_HOME_ORB', 'RLL_HOME_ORB%', 'RLL_HOME_ORtg', 'RLL_HOME_PF',
       'RLL_HOME_PTS', 'RLL_HOME_STL', 'RLL_HOME_STL%', 'RLL_HOME_TOV',
       'RLL_HOME_TOV%', 'RLL_HOME_TRB', 'RLL_HOME_TRB%', 'RLL_HOME_TS%',
       'RLL_HOME_USG%', 'RLL_HOME_eFG%', 'RLL_VISITOR_+/-', 'RLL_VISITOR_3P',
       'RLL_VISITOR_3P%', 'RLL_VISITOR_3PA', 'RLL_VISITOR_3PAr',
       'RLL_VISITOR_AST', 'RLL_VISITOR_AST%', 'RLL_VISITOR_BLK',
       'RLL_VISITOR_BLK%', 'RLL_VISITOR_DRB', 'RLL_VISITOR_DRB%',
       'RLL_VISITOR_DRtg', 'RLL_VISITOR_FG', 'RLL_VISITOR_FG%',
       'RLL_VISITOR_FGA', 'RLL_VISITOR_FT', 'RLL_VISITOR_FT%',
       'RLL_VISITOR_FTA', 'RLL_VISITOR_FTr', 'RLL_VISITOR_MP',
       'RLL_VISITOR_ORB', 'RLL_VISITOR_ORB%', 'RLL_VISITOR_ORtg',
       'RLL_VISITOR_PF', 'RLL_VISITOR_PTS', 'RLL_VISITOR_STL',
       'RLL_VISITOR_STL%', 'RLL_VISITOR_TOV', 'RLL_VISITOR_TOV%',
       'RLL_VISITOR_TRB', 'RLL_VISITOR_TRB%', 'RLL_VISITOR_TS%',
       'RLL_VISITOR_USG%', 'RLL_VISITOR_eFG%']

# %%
df['RLL_VISITOR_TRB'].head()
# Out:
# 0    39.797176
# 1    43.401215
# 2    40.233112
# 3    43.234541
# 4    43.031252
# Name: RLL_VISITOR_TRB, dtype: float64

# %%
df['RLL_VISITOR_TRB'].shift(1).head()
# Out:
# 0          NaN
# 1    39.797176
# 2    43.401215
# 3    40.233112
# 4    43.234541
# Name: RLL_VISITOR_TRB, dtype: float64

# %%
for col in cols_to_shift:
    df[col] = df[col].shift(1)

# %%
df.head()
# Out:
#    RLL_HOME_+/-  RLL_HOME_3P  RLL_HOME_3P%  RLL_HOME_3PA  RLL_HOME_3PAr  \
# 0           NaN          NaN           NaN           NaN            NaN
# 1           NaN     8.961052      0.469812     19.617369       0.257581
# 2           NaN     6.751715      0.393028     17.353576       0.197942
# 3           NaN     7.486581      0.378252     20.025380       0.234317
# 4           NaN     6.025633      0.331759     18.330054       0.233360
#
#    RLL_HOME_AST  RLL_HOME_AST%  RLL_HOME_BLK  RLL_HOME_BLK%  RLL_HOME_DRB  \
# 0           NaN            NaN           NaN            NaN           NaN
# 1     24.136962      63.995856      6.208568      10.053524     29.890207
# 2     24.795290      58.596547      6.382836       9.591609     33.158019
# 3     26.948306      65.177343      5.276481       7.932820     32.193527
# 4     21.751787      61.620177      4.778314       8.058415     31.846629
#
#    ...         DATE   START               VISITOR    PTS  \
# ...

# %%
df.drop('RLL_HOME_+/-', 1, inplace=True)

# %%
df.drop('RLL_VISITOR_+/-', 1, inplace=True)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    RLL_HOME_3P  RLL_HOME_3P%  RLL_HOME_3PA  RLL_HOME_3PAr  RLL_HOME_AST  \
# 1     8.961052      0.469812     19.617369       0.257581     24.136962
# 2     6.751715      0.393028     17.353576       0.197942     24.795290
# 3     7.486581      0.378252     20.025380       0.234317     26.948306
# 4     6.025633      0.331759     18.330054       0.233360     21.751787
# 5     6.683740      0.343413     19.458822       0.230180     22.835760
#
#    RLL_HOME_AST%  RLL_HOME_BLK  RLL_HOME_BLK%  RLL_HOME_DRB  RLL_HOME_DRB%  \
# 1      63.995856      6.208568      10.053524     29.890207      75.483565
# 2      58.596547      6.382836       9.591609     33.158019      75.221903
# 3      65.177343      5.276481       7.932820     32.193527      69.761589
# 4      61.620177      4.778314       8.058415     31.846629      78.065212
# 5      57.677442      6.413042       9.873795     32.089887      74.507820
#
#    ...         DATE   START               VISITOR    PTS  \
# ...

# %%
len(df)
# Out:
# 12946

# %%
## Difference of the strikes:

# %%
df.columns
# Out:
# Index(['RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA', 'RLL_HOME_3PAr',
#        'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK', 'RLL_HOME_BLK%',
#        'RLL_HOME_DRB', 'RLL_HOME_DRB%', 'RLL_HOME_DRtg', 'RLL_HOME_FG',
#        'RLL_HOME_FG%', 'RLL_HOME_FGA', 'RLL_HOME_FT', 'RLL_HOME_FT%',
#        'RLL_HOME_FTA', 'RLL_HOME_FTr', 'RLL_HOME_MP', 'RLL_HOME_ORB',
#        'RLL_HOME_ORB%', 'RLL_HOME_ORtg', 'RLL_HOME_PF', 'RLL_HOME_PTS',
#        'RLL_HOME_STL', 'RLL_HOME_STL%', 'RLL_HOME_TOV', 'RLL_HOME_TOV%',
#        'RLL_HOME_TRB', 'RLL_HOME_TRB%', 'RLL_HOME_TS%', 'RLL_HOME_USG%',
#        'RLL_HOME_eFG%', 'RLL_VISITOR_3P', 'RLL_VISITOR_3P%', 'RLL_VISITOR_3PA',
#        'RLL_VISITOR_3PAr', 'RLL_VISITOR_AST', 'RLL_VISITOR_AST%',
#        'RLL_VISITOR_BLK', 'RLL_VISITOR_BLK%', 'RLL_VISITOR_DRB',
#        'RLL_VISITOR_DRB%', 'RLL_VISITOR_DRtg', 'RLL_VISITOR_FG',
#        'RLL_VISITOR_FG%', 'RLL_VISITOR_FGA', 'RLL_VISITOR_FT',
# ...

# %%
home_cols = ['RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA', 'RLL_HOME_3PAr',
       'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK', 'RLL_HOME_BLK%',
       'RLL_HOME_DRB', 'RLL_HOME_DRB%', 'RLL_HOME_DRtg', 'RLL_HOME_FG',
       'RLL_HOME_FG%', 'RLL_HOME_FGA', 'RLL_HOME_FT', 'RLL_HOME_FT%',
       'RLL_HOME_FTA', 'RLL_HOME_FTr', 'RLL_HOME_MP', 'RLL_HOME_ORB',
       'RLL_HOME_ORB%', 'RLL_HOME_ORtg', 'RLL_HOME_PF', 'RLL_HOME_PTS',
       'RLL_HOME_STL', 'RLL_HOME_STL%', 'RLL_HOME_TOV', 'RLL_HOME_TOV%',
       'RLL_HOME_TRB', 'RLL_HOME_TRB%', 'RLL_HOME_TS%', 'RLL_HOME_USG%',
       'RLL_HOME_eFG%',]

# %%
len(home_cols)
# Out:
# 33

# %%
visitor_cols = ['RLL_VISITOR_3P', 'RLL_VISITOR_3P%', 'RLL_VISITOR_3PA',
       'RLL_VISITOR_3PAr', 'RLL_VISITOR_AST', 'RLL_VISITOR_AST%',
       'RLL_VISITOR_BLK', 'RLL_VISITOR_BLK%', 'RLL_VISITOR_DRB',
       'RLL_VISITOR_DRB%', 'RLL_VISITOR_DRtg', 'RLL_VISITOR_FG',
       'RLL_VISITOR_FG%', 'RLL_VISITOR_FGA', 'RLL_VISITOR_FT',
       'RLL_VISITOR_FT%', 'RLL_VISITOR_FTA', 'RLL_VISITOR_FTr',
       'RLL_VISITOR_MP', 'RLL_VISITOR_ORB', 'RLL_VISITOR_ORB%',
       'RLL_VISITOR_ORtg', 'RLL_VISITOR_PF', 'RLL_VISITOR_PTS',
       'RLL_VISITOR_STL', 'RLL_VISITOR_STL%', 'RLL_VISITOR_TOV',
       'RLL_VISITOR_TOV%', 'RLL_VISITOR_TRB', 'RLL_VISITOR_TRB%',
       'RLL_VISITOR_TS%', 'RLL_VISITOR_USG%', 'RLL_VISITOR_eFG%']

# %%
len(visitor_cols)
# Out:
# 33

# %%
for col in home_cols:
    #print(col)
    
    value = col.split('_')[-1]
    visitor_col = col.split('_')[0] + '_VISITOR_' + value
    
    print('DIF_'+ value + ' = ' + col + '-' + visitor_col)
    diff_col_name = 'DIF_'+ value
    df[diff_col_name] = df[col] - df[visitor_col]
# Out:
# DIF_3P = RLL_HOME_3P-RLL_VISITOR_3P
# DIF_3P% = RLL_HOME_3P%-RLL_VISITOR_3P%
# DIF_3PA = RLL_HOME_3PA-RLL_VISITOR_3PA
# DIF_3PAr = RLL_HOME_3PAr-RLL_VISITOR_3PAr
# DIF_AST = RLL_HOME_AST-RLL_VISITOR_AST
# DIF_AST% = RLL_HOME_AST%-RLL_VISITOR_AST%
# DIF_BLK = RLL_HOME_BLK-RLL_VISITOR_BLK
# DIF_BLK% = RLL_HOME_BLK%-RLL_VISITOR_BLK%
# DIF_DRB = RLL_HOME_DRB-RLL_VISITOR_DRB
# DIF_DRB% = RLL_HOME_DRB%-RLL_VISITOR_DRB%
# DIF_DRtg = RLL_HOME_DRtg-RLL_VISITOR_DRtg
# DIF_FG = RLL_HOME_FG-RLL_VISITOR_FG
# DIF_FG% = RLL_HOME_FG%-RLL_VISITOR_FG%
# DIF_FGA = RLL_HOME_FGA-RLL_VISITOR_FGA
# DIF_FT = RLL_HOME_FT-RLL_VISITOR_FT
# DIF_FT% = RLL_HOME_FT%-RLL_VISITOR_FT%
# DIF_FTA = RLL_HOME_FTA-RLL_VISITOR_FTA
# DIF_FTr = RLL_HOME_FTr-RLL_VISITOR_FTr
# DIF_MP = RLL_HOME_MP-RLL_VISITOR_MP
# DIF_ORB = RLL_HOME_ORB-RLL_VISITOR_ORB
# DIF_ORB% = RLL_HOME_ORB%-RLL_VISITOR_ORB%
# DIF_ORtg = RLL_HOME_ORtg-RLL_VISITOR_ORtg
# DIF_PF = RLL_HOME_PF-RLL_VISITOR_PF
# DIF_PTS = RLL_HOME_PTS-RLL_VISITOR_PTS
# ...

# %%
df.columns
# Out:
# Index(['RLL_HOME_3P', 'RLL_HOME_3P%', 'RLL_HOME_3PA', 'RLL_HOME_3PAr',
#        'RLL_HOME_AST', 'RLL_HOME_AST%', 'RLL_HOME_BLK', 'RLL_HOME_BLK%',
#        'RLL_HOME_DRB', 'RLL_HOME_DRB%',
#        ...
#        'DIF_PTS', 'DIF_STL', 'DIF_STL%', 'DIF_TOV', 'DIF_TOV%', 'DIF_TRB',
#        'DIF_TRB%', 'DIF_TS%', 'DIF_USG%', 'DIF_eFG%'],
#       dtype='object', length=109)

# %%
df = df.drop(home_cols, 1)

# %%
df = df.drop(visitor_cols, 1)

# %%
df.head()
# Out:
#          DATE   START               VISITOR    PTS                    HOME  \
# 1  2009-10-27   8:30p    Washington Wizards  102.0        Dallas Mavericks
# 2  2009-10-27  10:30p  Los Angeles Clippers   92.0      Los Angeles Lakers
# 3  2009-10-27  10:00p       Houston Rockets   87.0  Portland Trail Blazers
# 4  2009-10-28   7:00p        Indiana Pacers  109.0           Atlanta Hawks
# 5  2009-10-28   7:30p     Charlotte Hornets   59.0          Boston Celtics
#
#    PTS.1   ATTEND  DAY_OF_WEEK  LABEL  YEAR    ...       DIF_PTS   DIF_STL  \
# 1   91.0  19871.0            2      0  2010    ...      0.320688 -2.628544
# 2   99.0  18997.0            2      1  2010    ...     19.825059  3.554096
# 3   96.0  20403.0            2      1  2010    ...      3.676120  0.221028
# 4  120.0  17998.0            3      1  2010    ...     -5.399823 -5.002850
# 5   92.0  18624.0            3      1  2010    ...      8.576086 -1.430137
#
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'START', 'VISITOR', 'PTS', 'HOME', 'PTS.1', 'ATTEND',
#        'DAY_OF_WEEK', 'LABEL', 'YEAR', 'DIF_3P', 'DIF_3P%', 'DIF_3PA',
#        'DIF_3PAr', 'DIF_AST', 'DIF_AST%', 'DIF_BLK', 'DIF_BLK%', 'DIF_DRB',
#        'DIF_DRB%', 'DIF_DRtg', 'DIF_FG', 'DIF_FG%', 'DIF_FGA', 'DIF_FT',
#        'DIF_FT%', 'DIF_FTA', 'DIF_FTr', 'DIF_MP', 'DIF_ORB', 'DIF_ORB%',
#        'DIF_ORtg', 'DIF_PF', 'DIF_PTS', 'DIF_STL', 'DIF_STL%', 'DIF_TOV',
#        'DIF_TOV%', 'DIF_TRB', 'DIF_TRB%', 'DIF_TS%', 'DIF_USG%', 'DIF_eFG%'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 PTS         PTS.1        ATTEND   DAY_OF_WEEK         LABEL  \
# count  12946.000000  12946.000000  12946.000000  12946.000000  12946.000000
# mean     100.606288    103.458674  17677.083346      4.025877      0.594701
# std       12.535817     12.554193   2440.301165      1.961119      0.490969
# min       56.000000     59.000000   7244.000000      1.000000      0.000000
# 25%       92.000000     95.000000  16300.250000      2.000000      0.000000
# 50%      100.000000    103.000000  18203.000000      4.000000      1.000000
# 75%      109.000000    112.000000  19557.000000      6.000000      1.000000
# max      149.000000    152.000000  23152.000000      7.000000      1.000000
#
#                YEAR        DIF_3P       DIF_3P%       DIF_3PA      DIF_3PAr  \
# count  12946.000000  12946.000000  12946.000000  12946.000000  12946.000000
# mean    2014.582960      0.164709      0.007669     -0.037027     -0.000599
# ...

# %%
## EDA OF THE NEW COLS:

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#      PTS  PTS.1   ATTEND  DAY_OF_WEEK  LABEL  YEAR    DIF_3P   DIF_3P%  \
# 1  102.0   91.0  19871.0            2      0  2010  1.881591  0.097268
# 2   92.0   99.0  18997.0            2      1  2010  2.189669  0.078921
# 3   87.0   96.0  20403.0            2      1  2010  2.490805  0.015719
# 4  109.0  120.0  17998.0            3      1  2010 -3.344095 -0.052038
# 5   59.0   92.0  18624.0            3      1  2010  0.714998  0.064470
#
#     DIF_3PA  DIF_3PAr    ...       DIF_PTS   DIF_STL  DIF_STL%   DIF_TOV  \
# 1  2.062168  0.025213    ...      0.320688 -2.628544 -2.570109 -1.152155
# 2  2.658110  0.011308    ...     19.825059  3.554096  3.461778 -3.608227
# 3  6.319951  0.057709    ...      3.676120  0.221028  0.007088  1.218171
# 4 -6.557400 -0.052346    ...     -5.399823 -5.002850 -4.768417 -5.237805
# 5 -1.591505 -0.029186    ...      8.576086 -1.430137 -1.045529 -5.821975
#
#    DIF_TOV%   DIF_TRB  DIF_TRB%   DIF_TS%  DIF_USG%  DIF_eFG%
# ...

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %% [markdown]
# ### Correlation about points made by the home team (PTS.1) vs rest of variables
# ### and points made by the visitor team (PTS)

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['PTS'])

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['PTS.1'])

# %%
import operator

individual_features_df = []
for i in range(0, len(df_num.columns) - 1): # -1 because the last column is SalePrice
    tmpDf = df_num[[df_num.columns[i], 'PTS']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['PTS'].iloc[0] for feature in individual_features_df}
all_correlations['PTS'] = 1
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
print('Most correlated features with VISITOR PTS ')
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
# Most correlated features with VISITOR PTS
#         DIF_FGA: -0.16290890286466814
#          ATTEND: -0.038816307328458775
#         DIF_FTr: -0.032159074479309484
#         DIF_FTA: -0.02763184369047865
#          DIF_FT: -0.023656226360608986
#        DIF_AST%: -0.015335309644356587
#        DIF_ORtg: -0.0134464993437511
#         DIF_FG%: -0.013148173779899595
#         DIF_TS%: -0.012604976485575346
#         DIF_BLK: -0.01164272152088661
#        DIF_BLK%: -0.009802676392060724
#         DIF_AST: -0.005988966993637887
#         DIF_3P%: -0.0059222323037955915
#        DIF_STL%: -0.0050092641074099475
#         DIF_STL: -0.0023658095388593933
#         DIF_PTS: -0.0010781697713326736
#         DIF_FT%: -0.0004575682592466907
#     DAY_OF_WEEK: -0.0003271286163809065
#        DIF_ORB%: 0.004879522554371714
#        DIF_3PAr: 0.0058308228287359066
#          DIF_FG: 0.008975477518865157
#         DIF_ORB: 0.009120975539120614
#        DIF_DRtg: 0.010042778495325855
# ...

# %%
import operator

individual_features_df = []
for i in range(0, len(df_num.columns) - 1): # -1 because the last column is SalePrice
    tmpDf = df_num[[df_num.columns[i], 'PTS.1']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['PTS.1'].iloc[0] for feature in individual_features_df}
all_correlations['PTS.1'] = 1
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
print('Most correlated features with HOME PTS ')
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
# Most correlated features with HOME PTS
#         DIF_FGA: -0.14990292379521328
#         DIF_FTr: -0.0299988678637071
#         DIF_FTA: -0.025725393939833346
#          DIF_FT: -0.023394453139394814
#         DIF_FG%: -0.018691157574055015
#        DIF_AST%: -0.018667590555287758
#         DIF_TS%: -0.01637189042393407
#        DIF_ORtg: -0.011727985956114878
#         DIF_AST: -0.010156037938874301
#        DIF_BLK%: -0.009228958910994699
#         DIF_BLK: -0.008530039520161629
#         DIF_3P%: -0.006505609465102717
#        DIF_STL%: -0.005715654870667334
#         DIF_PTS: -0.00512739238981658
#     DAY_OF_WEEK: -0.0045642077899806415
#         DIF_STL: -0.00434350761973996
#         DIF_FT%: -0.0014449072681627152
#          DIF_FG: 0.002483090178766765
#          DIF_MP: 0.006370845968696673
#        DIF_TOV%: 0.007050644271643544
#          DIF_PF: 0.007931397669029068
#        DIF_DRtg: 0.007997680734258775
#        DIF_3PAr: 0.00924506178003732
# ...

# %%
corr = df_num.drop('PTS', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
corr = df_num.drop('PTS.1', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.8) | (corr <= -0.3)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
df.head()
# Out:
#          DATE   START               VISITOR    PTS                    HOME  \
# 1  2009-10-27   8:30p    Washington Wizards  102.0        Dallas Mavericks
# 2  2009-10-27  10:30p  Los Angeles Clippers   92.0      Los Angeles Lakers
# 3  2009-10-27  10:00p       Houston Rockets   87.0  Portland Trail Blazers
# 4  2009-10-28   7:00p        Indiana Pacers  109.0           Atlanta Hawks
# 5  2009-10-28   7:30p     Charlotte Hornets   59.0          Boston Celtics
#
#    PTS.1   ATTEND  DAY_OF_WEEK  LABEL  YEAR    ...       DIF_PTS   DIF_STL  \
# 1   91.0  19871.0            2      0  2010    ...      0.320688 -2.628544
# 2   99.0  18997.0            2      1  2010    ...     19.825059  3.554096
# 3   96.0  20403.0            2      1  2010    ...      3.676120  0.221028
# 4  120.0  17998.0            3      1  2010    ...     -5.399823 -5.002850
# 5   92.0  18624.0            3      1  2010    ...      8.576086 -1.430137
#
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'START', 'VISITOR', 'PTS', 'HOME', 'PTS.1', 'ATTEND',
#        'DAY_OF_WEEK', 'LABEL', 'YEAR', 'DIF_3P', 'DIF_3P%', 'DIF_3PA',
#        'DIF_3PAr', 'DIF_AST', 'DIF_AST%', 'DIF_BLK', 'DIF_BLK%', 'DIF_DRB',
#        'DIF_DRB%', 'DIF_DRtg', 'DIF_FG', 'DIF_FG%', 'DIF_FGA', 'DIF_FT',
#        'DIF_FT%', 'DIF_FTA', 'DIF_FTr', 'DIF_MP', 'DIF_ORB', 'DIF_ORB%',
#        'DIF_ORtg', 'DIF_PF', 'DIF_PTS', 'DIF_STL', 'DIF_STL%', 'DIF_TOV',
#        'DIF_TOV%', 'DIF_TRB', 'DIF_TRB%', 'DIF_TS%', 'DIF_USG%', 'DIF_eFG%'],
#       dtype='object')

# %%
X = df.copy()

# %%
X = X.drop(['DATE', 'START', 'VISITOR', 'PTS', 'HOME', 'PTS.1', 'ATTEND',
       'DAY_OF_WEEK','YEAR'], 1)

# %%
X.tail()
# Out:
#        LABEL    DIF_3P   DIF_3P%   DIF_3PA  DIF_3PAr   DIF_AST   DIF_AST%  \
# 12998      1 -1.263284 -0.052374  0.841467  0.017328  5.118350   7.117111
# 12999      1  1.318666  0.004820  2.981561  0.069578  2.642817  14.588843
# 13000      0 -0.153942 -0.002946  0.116088  0.020321 -0.235411   3.170741
# 13001      1  2.438379  0.013084  6.049456  0.063384 -3.868782  -5.977578
# 13002      1 -0.083883  0.049278 -5.046344 -0.026737 -1.905142  -1.687107
#
#         DIF_BLK  DIF_BLK%   DIF_DRB    ...       DIF_PTS   DIF_STL  DIF_STL%  \
# 12998  1.549279  2.361363  0.326235    ...      1.314286 -0.305348 -0.204520
# 12999 -0.686841 -1.005613  0.960371    ...     -1.966497 -1.799270 -1.275806
# 13000 -1.410235 -2.929595  7.836064    ...      0.262491 -1.138549 -1.322366
# 13001  1.670428  4.450310  4.533743    ...    -11.087436  0.581533  0.973961
# 13002  1.360176  2.072939 -0.974769    ...     -1.102991  1.156133  1.276982
#
# ...

# %%
X.columns
# Out:
# Index(['LABEL', 'DIF_3P', 'DIF_3P%', 'DIF_3PA', 'DIF_3PAr', 'DIF_AST',
#        'DIF_AST%', 'DIF_BLK', 'DIF_BLK%', 'DIF_DRB', 'DIF_DRB%', 'DIF_DRtg',
#        'DIF_FG', 'DIF_FG%', 'DIF_FGA', 'DIF_FT', 'DIF_FT%', 'DIF_FTA',
#        'DIF_FTr', 'DIF_MP', 'DIF_ORB', 'DIF_ORB%', 'DIF_ORtg', 'DIF_PF',
#        'DIF_PTS', 'DIF_STL', 'DIF_STL%', 'DIF_TOV', 'DIF_TOV%', 'DIF_TRB',
#        'DIF_TRB%', 'DIF_TS%', 'DIF_USG%', 'DIF_eFG%'],
#       dtype='object')

# %%
cols_to_drop_diff = []

for col in X.columns:
    if not '%' in col:
        cols_to_drop_diff.append(col)

# %%
cols_to_drop_diff
# Out:
# ['LABEL',
#  'DIF_3P',
#  'DIF_3PA',
#  'DIF_3PAr',
#  'DIF_AST',
#  'DIF_BLK',
#  'DIF_DRB',
#  'DIF_DRtg',
#  'DIF_FG',
#  'DIF_FGA',
#  'DIF_FT',
#  'DIF_FTA',
#  'DIF_FTr',
#  'DIF_MP',
#  'DIF_ORB',
#  'DIF_ORtg',
#  'DIF_PF',
#  'DIF_PTS',
#  'DIF_STL',
#  'DIF_TOV',
#  'DIF_TRB']

# %%
"""
X_new = X.drop(['DIF_3P',
 'DIF_3PA',
 'DIF_3PAr',
 'DIF_FG',
 'DIF_FT',
 'DIF_FTr',
 'DIF_ORB',
 'DIF_ORtg',
 'DIF_PF',
 'DIF_PTS',
 'DIF_STL',
 'DIF_TOV',
 'DIF_TRB', 'DIF_USG%'], 1)
"""
# Out:
# "\nX_new = X.drop(['DIF_3P',\n 'DIF_3PA',\n 'DIF_3PAr',\n 'DIF_FG',\n 'DIF_FT',\n 'DIF_FTr',\n 'DIF_ORB',\n 'DIF_ORtg',\n 'DIF_PF',\n 'DIF_PTS',\n 'DIF_STL',\n 'DIF_TOV',\n 'DIF_TRB', 'DIF_USG%'], 1)\n"

# %%
X.columns
# Out:
# Index(['LABEL', 'DIF_3P', 'DIF_3P%', 'DIF_3PA', 'DIF_3PAr', 'DIF_AST',
#        'DIF_AST%', 'DIF_BLK', 'DIF_BLK%', 'DIF_DRB', 'DIF_DRB%', 'DIF_DRtg',
#        'DIF_FG', 'DIF_FG%', 'DIF_FGA', 'DIF_FT', 'DIF_FT%', 'DIF_FTA',
#        'DIF_FTr', 'DIF_MP', 'DIF_ORB', 'DIF_ORB%', 'DIF_ORtg', 'DIF_PF',
#        'DIF_PTS', 'DIF_STL', 'DIF_STL%', 'DIF_TOV', 'DIF_TOV%', 'DIF_TRB',
#        'DIF_TRB%', 'DIF_TS%', 'DIF_USG%', 'DIF_eFG%'],
#       dtype='object')

# %%
X_new = X[['LABEL', 'DIF_3P%', 'DIF_AST',
        'DIF_BLK', 'DIF_DRB', 'DIF_DRtg',
       'DIF_FG%', 'DIF_FT%', 
       'DIF_ORB', 'DIF_ORtg',
       'DIF_PTS', 'DIF_STL',  'DIF_TOV','DIF_TRB',
       'DIF_TS%', 'DIF_eFG%']]

# %%
X_new.head()
# Out:
#    LABEL   DIF_3P%   DIF_AST   DIF_BLK   DIF_DRB  DIF_DRtg   DIF_FG%  \
# 1      0  0.097268  1.581482  0.967493 -1.967703  6.423544  0.013888
# 2      1  0.078921  8.351389  1.035633  1.742091 -8.267250  0.066708
# 3      1  0.015719  6.375744 -1.514929  0.412762 -3.793953 -0.013086
# 4      1 -0.052038 -2.271225  0.503060  2.187712 -3.727221 -0.003773
# 5      1  0.064470  5.393619  0.288747  0.019764 -0.301610  0.033937
#
#     DIF_FT%   DIF_ORB   DIF_ORtg    DIF_PTS   DIF_STL   DIF_TOV   DIF_TRB  \
# 1 -0.028235  0.295122   4.089053   0.320688 -2.628544 -1.152155 -1.672581
# 2  0.150668 -0.052264  16.896976  19.825059  3.554096 -3.608227  1.689827
# 3  0.001941  3.124302   1.848652   3.676120  0.221028  1.218171  3.537064
# 4  0.000258 -1.898991   4.410438  -5.399823 -5.002850 -5.237805  0.288721
# 5 -0.004156  1.817499  15.391591   8.576086 -1.430137 -5.821975  1.837263
#
#     DIF_TS%  DIF_eFG%
# 1  0.011759  0.025744
# 2  0.072414  0.076531
# 3 -0.013919 -0.001740
# ...

# %%
y = X_new['LABEL']

X_new = X_new.drop('LABEL', 1)

# %% [markdown]
# ## Scaling Values

# %%
from sklearn import preprocessing

# %%
X_scaled = preprocessing.scale(np.array(X_new))

# %%
X_scaled = pd.DataFrame(X_scaled)

# %%
X_scaled.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.400151  0.088481  0.297083 -0.833752  1.270904  0.078411 -0.431860
# 1  1.113454  1.885426  0.335419  0.242077 -0.726194  1.529653  2.130541
# 2  0.125798  1.361028 -1.099535 -0.143424 -0.118084 -0.662691  0.000343
# 3 -0.933031 -0.934147  0.035791  0.371306 -0.109013 -0.406810 -0.023760
# 4  0.887619  1.100342 -0.084782 -0.257392  0.356672  0.629266 -0.086979
#
#          7         8         9         10        11        12        13  \
# 0  0.005235  0.152033 -0.293832 -1.344533 -0.363254 -0.665875 -0.016014
# 1 -0.125374  1.840140  2.033163  1.756579 -1.352979  0.116668  1.445365
# 2  1.068947 -0.143256  0.106492  0.084766  0.591918  0.546581 -0.634694
# 3 -0.819705  0.194392 -0.976326 -2.535447 -2.009651 -0.209415 -0.281569
# 4  0.577617  1.641727  0.691089 -0.743432 -2.245055  0.150982  0.423452
#
#          14
# 0  0.315145
# 1  1.478600
# 2 -0.314485
# 3 -0.716939
# 4  0.558925

# %% [markdown]
# ## ML

# %% [markdown]
# ### Train Test Split

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
#y = X_new['LABEL']

# %%
#X_new = X_new.drop('LABEL', 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(solver='liblinear',
                         multi_class='ovr').fit(X_train, y_train)

# %%
predictions = clf.predict(X_test)

# %%
clf.score(X_train, y_train)
# Out:
# 0.5946029457204656

# %%
clf.score(X_test, y_test)
# Out:
# 0.5949953660797034

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca = pd.DataFrame(X_pca)

# %%
X_pca.head()
# Out:
#           0         1
# 0  0.330949  1.367367
# 1  4.499244 -0.127504
# 2 -0.537305 -0.567164
# 3 -1.287115  0.366267
# 4  1.960291  0.400345

# %%
ax = sns.scatterplot(data=X_pca)

# %%
from sklearn.cluster import MeanShift

# %% [markdown]
# ## CATBOOST

# %%
from catboost import CatBoostClassifier, Pool

test_data = catboost_pool = Pool(X_train, 
                                 y_train)

model = CatBoostClassifier(iterations=600, 
                           depth=7, 
                           learning_rate=0.001, 
                           loss_function='Logloss', 
                           logging_level='Verbose')
#train the model
model.fit(X_train, y_train)
# make the prediction using the resulting model
preds_class = model.predict(X_test)
preds_proba = model.predict_proba(X_test)
print("class = ", preds_class)
print("proba = ", preds_proba)
# Out:
# 0:	learn: 0.6931049	total: 90.2ms	remaining: 54s
# 1:	learn: 0.6930585	total: 150ms	remaining: 45s
# 2:	learn: 0.6930148	total: 216ms	remaining: 43s
# 3:	learn: 0.6929729	total: 279ms	remaining: 41.6s
# 4:	learn: 0.6929292	total: 340ms	remaining: 40.5s
# 5:	learn: 0.6928871	total: 412ms	remaining: 40.8s
# 6:	learn: 0.6928466	total: 495ms	remaining: 41.9s
# 7:	learn: 0.6928031	total: 570ms	remaining: 42.2s
# 8:	learn: 0.6927643	total: 635ms	remaining: 41.7s
# 9:	learn: 0.6927191	total: 698ms	remaining: 41.2s
# 10:	learn: 0.6926767	total: 771ms	remaining: 41.3s
# 11:	learn: 0.6926368	total: 877ms	remaining: 43s
# 12:	learn: 0.6925865	total: 950ms	remaining: 42.9s
# 13:	learn: 0.6925386	total: 1.02s	remaining: 42.6s
# 14:	learn: 0.6924931	total: 1.09s	remaining: 42.5s
# 15:	learn: 0.6924492	total: 1.18s	remaining: 43.1s
# 16:	learn: 0.6924084	total: 1.24s	remaining: 42.5s
# 17:	learn: 0.6923654	total: 1.31s	remaining: 42.5s
# 18:	learn: 0.6923208	total: 1.38s	remaining: 42.1s
# ...

# %%
model.score(X_train, y_train)
# Out:
# 0.5946029457204656

# %%
model.score(X_test, y_test)
# Out:
# 0.5949953660797034
